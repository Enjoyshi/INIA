# %% [markdown]
# # <center> Lab 04: Unsupervise Learning: K-Means Algorithm<br> <small>Réda DEHAK<br> 5 June 2020</small> </center>
#
#
# The goal of this lab is :
#     - understand the K-Means algorithm
#     - Use K-Means for classification
#     - Use K-Means for quantification

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Part 1: using KMeans Class
#
# First, let's generate a two-dimensional dataset containing four distinct blobs. To emphasize that this is an unsupervised algorithm, we will leave the labels out of the visualization

# %%
from sklearn.datasets import make_blobs

X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %% [markdown]
# By eye, it is relatively easy to pick out the four clusters. Test if we will have the same result with the k-means algorithm?

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 4, init = 'random', random_state = 0, n_init = 4, algorithm='full')
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# - ReRun the K-Mean with a "random_seed=42"
# - Plot the result, what happened?

# %%
def find_clusters(X, n_clus, rseed=0):
    kmeans = KMeans(n_clusters = n_clus, init = 'random', random_state = rseed, n_init = 10, algorithm='full')
    kmeans.fit(X)
    y_kmeans = kmeans.predict(X)
    plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
    centers = kmeans.cluster_centers_
    plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
    
find_clusters(X, 4, 42)

# %% [markdown]
# - Change the parameter "n_init = 10" and see the result?
# - What happened?

# %%
kmeans = KMeans(n_clusters = 8, init = 'random', random_state = 0, n_init = 4, algorithm='full')
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# - Use different values for "n_cluster" and see the result of the clustering?
# - Conclude?

# %% [markdown]
# ## Part 2: No Euclidean Space
#
# Know we try to work with a new dataset

# %%
from sklearn.datasets import make_circles

X, y_true = make_circles(n_samples=400, factor=.3, noise=.05, random_state=0)

plt.scatter(X[:, 0], X[:, 1], s=50);

# %% [markdown]
# By eye, it is relatively easy to pick out the two clusters. Test if we will have the same result with the k-means algorithm?

# %%
kmeans = KMeans(n_clusters = 2, init = 'random', random_state = 0, n_init = 4, algorithm='full')
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# - Is it possible or not to have the exact classification with KMeans algorithm? if yes give the code?

# %%
from sklearn.preprocessing import PolynomialFeatures
def transform(x):
    #return PolynomialFeatures(2).fit_transform(x)
    return np.vstack((x[:, 0] ** 2 + x[:, 1] ** 2))

kmeans = KMeans(n_clusters = 2, init = 'random', random_state = 0, n_init = 4, algorithm='full')
kmeans.fit(transform(X))
y_kmeans = kmeans.predict(transform(X))
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

# centers = kmeans.cluster_centers_
# plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# ## Part 3: Image clustering
#
# Let's take a look at applying k-means on the same simple digits dataset used in the previous labs. we will attempt to use k-means to try to identify similar digits without using the original label informations; this might be similar to a first step in extracting meaning from a new dataset about which you don't have any a priori label information.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
print(digits.data.shape)
# Out:
# (1797, 64)

# %%
# We use the default values for other parameters of KMeans Class
kmeans = KMeans(n_clusters=10, random_state=0) 
clusters = kmeans.fit_predict(digits.data)
kmeans.cluster_centers_.shape
# Out:
# (10, 64)

# %% [markdown]
# The result is 10 clusters in 64 dimensions. Notice that the cluster centers themselves are 64-dimensional points, and can themselves be interpreted as the "typical" digit within the cluster. Let's see what these cluster centers look like:

# %%
fig, ax = plt.subplots(2, 5, figsize=(8, 3))
centers = kmeans.cluster_centers_.reshape(10, 8, 8)
for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='nearest', cmap=plt.cm.binary)

# %% [markdown]
# We see that even without the labels, KMeans is able to find clusters whose centers are recognizable digits, with perhaps the exception of two digits.
#
# Because k-means knows nothing about the identity of the cluster, the 0–9 labels may be permuted. We can fix this by matching each learned cluster label with the true labels found in them:

# %%
from scipy.stats import mode

labels = np.zeros_like(clusters)
for i in range(10):
    mask = (clusters == i)
    labels[mask] = mode(digits.target[mask])[0]

# %% [markdown]
# Now we can check how accurate our unsupervised clustering was in finding similar digits within the data:

# %%
from sklearn.metrics import accuracy_score
accuracy_score(digits.target, labels)
# Out:
# 0.7935447968836951

# %% [markdown]
# With just a simple k-means algorithm, we discovered the correct grouping for 80% of the input digits! Let's check the confusion matrix for this:

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

mat = confusion_matrix(digits.target, labels)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=digits.target_names,
            yticklabels=digits.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# ## Part 4: Image Quantization
#
# One interesting application of clustering is in color compression within images. For example, imagine you have an RGB image, for each pixel we use 3 bytes to represent the colors. In most images, a large number of the colors will be unused, and many of the pixels in the image will have similar or even identical colors. So we can reduce the number of colors used in an image to use less memory size
#
# We will use 5 different images and try to find the best number of colors to have a good visual image for each one.

# %%
import matplotlib.image as mpimg
from sklearn.datasets import load_sample_image
#image = mpimg.imread("enfant1.png")[:,:,0:3]
#image = mpimg.imread("enfant2.png")[:,:,0:3]
#image = mpimg.imread("lena.png")
image = mpimg.imread("baboon.png")
#image = load_sample_image("china.jpg") / 255.
#image = load_sample_image("flower.jpg") / 255.
#image = mpimg.imread("PL_1.png")[:,:,0:3]

ax = plt.axes(xticks=[], yticks=[])
ax.imshow(image)
print(image.shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# One way we can view this set of pixels is as a cloud of points in a three-dimensional color space. We will reshape the data to [n_samples x n_features].

# %%
data = image.reshape(-1, 3)
data.shape
# Out:
# (262144, 3)

# %% [markdown]
# We can visualize these pixels in this 3D color space.

# %%
R, G, B = data.T

ax = plt.axes(projection='3d')
ax.scatter3D(R, G, B, c=data);

# %% [markdown]
# Now let's reduce these 16 million colors to just 16 colors, using a k-means clustering across the pixel space.

# %%
kmeans = KMeans(8)
kmeans.fit(data)
new_colors = kmeans.cluster_centers_[kmeans.predict(data)]

ax = plt.axes(projection='3d')
ax.scatter3D(R, G, B, c=new_colors);

# %%
image_recolored = new_colors.reshape(image.shape)

fig, ax = plt.subplots(1, 2, figsize=(16, 6),
                       subplot_kw=dict(xticks=[], yticks=[]))
fig.subplots_adjust(wspace=0.05)
ax[0].imshow(image)
ax[0].set_title('Original Image', size=16)
ax[1].imshow(image_recolored)
ax[1].set_title('16-color Image', size=16);

# %% [markdown]
# Some detail is certainly lost in the rightmost panel, but the overall image is still easily recognizable. This image on the right achieves a compression factor of around 1 million! While this is an interesting application of k-means, there are certainly better way to compress information in images. But the example shows the power of thinking outside of the box with unsupervised methods like k-means.

# %% [markdown]
# - Compare the result of the different images?
# - Conclude on the quality of the compression depending on image contents?

# %% [markdown]
# Plus les couleurs de l'image sont riches, et plus l'image est détaillée, plus le découpage en 16 couleurs est moins précis.
